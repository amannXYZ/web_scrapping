# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1' ,headers = headers).text

# %%
soup = BeautifulSoup(webpage , 'lxml')

# %%
company = soup.find_all('div' , class_ = 'companyCardWrapper')

# %%
len(company)
# Out:
# 20

# %%
name = []
ctype = []

for i in company:
    name.append(i.find('h2').text.strip())
    ctype.append(i.find('span',class_='companyCardWrapper__interLinking').text.strip())

# %%
ctype
# Out:
# ['IT Services & Consulting | Bengaluru +448 other locations',
#  'IT Services & Consulting | Bengaluru +261 other locations',
#  'IT Services & Consulting | Hyderabad +375 other locations',
#  'IT Services & Consulting | Hyderabad +233 other locations',
#  'IT Services & Consulting | Bengaluru +186 other locations',
#  'Banking | Mumbai +1857 other locations',
#  'IT Services & Consulting | Bengaluru +247 other locations',
#  'IT Services & Consulting | Chennai +231 other locations',
#  'Banking | Mumbai +1446 other locations',
#  'IT Services & Consulting | Hyderabad +323 other locations',
#  'Analytics & KPO | Hyderabad +181 other locations',
#  'BPO | Mumbai +258 other locations',
#  'Telecom | Mumbai +1965 other locations',
#  'Banking | Mumbai +1530 other locations',
#  'BPO | Bengaluru +185 other locations',
#  'Internet | Bengaluru +520 other locations',
#  'Retail | Mumbai +1166 other locations',
#  'BPO | Noida +53 other locations',
#  'IT Services & Consulting | Bengaluru +145 other locations',
#  'NBFC | Mumbai +1098 other locations']

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Wipro',
#  'Cognizant',
#  'Capgemini',
#  'HDFC Bank',
#  'Infosys',
#  'HCLTech',
#  'ICICI Bank',
#  'Tech Mahindra',
#  'Genpact',
#  'TP',
#  'Jio',
#  'Axis Bank',
#  'Concentrix Corporation',
#  'Amazon',
#  'Reliance Retail',
#  'iEnergizer',
#  'LTIMindtree',
#  'HDB Financial Services']

# %%
d = {'name':name , 'company_type':ctype}
df = pd.DataFrame(d)
df
# Out:
#                       name                                       company_type
# 0                      TCS  IT Services & Consulting | Bengaluru +448 othe...
# 1                Accenture  IT Services & Consulting | Bengaluru +261 othe...
# 2                    Wipro  IT Services & Consulting | Hyderabad +375 othe...
# 3                Cognizant  IT Services & Consulting | Hyderabad +233 othe...
# 4                Capgemini  IT Services & Consulting | Bengaluru +186 othe...
# 5                HDFC Bank             Banking | Mumbai +1857 other locations
# 6                  Infosys  IT Services & Consulting | Bengaluru +247 othe...
# 7                  HCLTech  IT Services & Consulting | Chennai +231 other ...
# 8               ICICI Bank             Banking | Mumbai +1446 other locations
# 9            Tech Mahindra  IT Services & Consulting | Hyderabad +323 othe...
# 10                 Genpact   Analytics & KPO | Hyderabad +181 other locations
# 11                      TP                  BPO | Mumbai +258 other locations
# 12                     Jio             Telecom | Mumbai +1965 other locations
# 13               Axis Bank             Banking | Mumbai +1530 other locations
# 14  Concentrix Corporation               BPO | Bengaluru +185 other locations
# 15                  Amazon          Internet | Bengaluru +520 other locations
# 16         Reliance Retail              Retail | Mumbai +1166 other locations
# 17              iEnergizer                    BPO | Noida +53 other locations
# 18             LTIMindtree  IT Services & Consulting | Bengaluru +145 othe...
# 19  HDB Financial Services                NBFC | Mumbai +1098 other locations

# %%
final = pd.DataFrame()

for j in range(1,10):
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage = requests.get( url,headers = headers).text
    soup = BeautifulSoup(webpage , 'lxml')
    company = soup.find_all('div' , class_ = 'companyCardWrapper')
    name = []
    ctype = []
    for i in company:
        name.append(i.find('h2').text.strip())
        ctype.append(i.find('span',class_='companyCardWrapper__interLinking').text.strip())
    d = {'name':name , 'company_type':ctype}
    df = pd.DataFrame(d)
    final = pd.concat([final, df], ignore_index=True)

# %%
final.head(20)
# Out:
#                       name                                       company_type
# 0                      TCS  IT Services & Consulting | Bengaluru +448 othe...
# 1                Accenture  IT Services & Consulting | Bengaluru +261 othe...
# 2                    Wipro  IT Services & Consulting | Hyderabad +375 othe...
# 3                Cognizant  IT Services & Consulting | Hyderabad +233 othe...
# 4                Capgemini  IT Services & Consulting | Bengaluru +186 othe...
# 5                HDFC Bank             Banking | Mumbai +1857 other locations
# 6                  Infosys  IT Services & Consulting | Bengaluru +247 othe...
# 7                  HCLTech  IT Services & Consulting | Chennai +231 other ...
# 8               ICICI Bank             Banking | Mumbai +1446 other locations
# 9            Tech Mahindra  IT Services & Consulting | Hyderabad +323 othe...
# 10                 Genpact   Analytics & KPO | Hyderabad +181 other locations
# 11                      TP                  BPO | Mumbai +258 other locations
# 12                     Jio             Telecom | Mumbai +1965 other locations
# 13               Axis Bank             Banking | Mumbai +1530 other locations
# 14  Concentrix Corporation               BPO | Bengaluru +185 other locations
# 15                  Amazon          Internet | Bengaluru +520 other locations
# 16         Reliance Retail              Retail | Mumbai +1166 other locations
# 17              iEnergizer                    BPO | Noida +53 other locations
# 18             LTIMindtree  IT Services & Consulting | Bengaluru +145 othe...
# 19  HDB Financial Services                NBFC | Mumbai +1098 other locations
